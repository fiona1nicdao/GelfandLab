# %% [markdown]
# Add constrast and brightness to all images for experiement

# %%
import imagej
ij = imagej.init('sc.fiji:fiji:2.1.1')
ij.getVersion()
# Out:
# cjdk: Installing Maven to /Users/fionanicdao/Library/Caches/cjdk
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:  --:--:--
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:10
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:18
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:35
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:29
# Download   0% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:25
# Download   1% of   8.7 MiB |             | Elapsed Time: 0:00:00 ETA:   0:01:25
# Download   1% of   8.7 MiB |             | Elapsed Time: 0:00:01 ETA:   0:01:24
# Download   1% of   8.7 MiB |             | Elapsed Time: 0:00:01 ETA:   0:01:22
# Download   1% of   8.7 MiB |             | Elapsed Time: 0:00:01 ETA:   0:01:20
# Download   1% of   8.7 MiB |             | Elapsed Time: 0:00:01 ETA:   0:01:20
# ...

# %%
import pandas as pd
